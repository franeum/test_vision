# %%
from ultralytics import YOLO
import time

# %%
# Load a model
model = YOLO('yolov8n-cls.pt')  # load an official model
#model = YOLO('path/to/best.pt')  # load a custom trained

# %%
start = time.time()
results = model('test.jpg')
print(time.time() - start)
# Out:
# image 1/1 /home/neum/Documenti/object-detection-opencv/test.jpg: 224x224 academic_gown 0.44, mortarboard 0.26, groom 0.12, suit 0.06, bow_tie 0.03, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# 0.03420448303222656

# %%
results[0].verbose()
# Out:
# 'academic_gown 0.44, mortarboard 0.26, groom 0.12, suit 0.06, bow_tie 0.03, '

# %%
type(results)
# Out:
# list

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('./RECORD/_test0.jpg')
#results[0].boxes.cls.tolist().count(0.0)
# Out:
# image 1/1 /home/neum/Documenti/object-detection-opencv/RECORD/_test0.jpg: 480x640 1 person, 150.8ms
# Speed: 3.7ms preprocess, 150.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
dir(results[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_keys',
#  'boxes',
#  'cpu',
#  'cuda',
#  'keypoints',
#  'keys',
#  'masks',
#  'names',
#  'new',
#  'numpy',
#  'orig_img',
#  'orig_shape',
#  'pandas',
#  'path',
#  'plot',
#  'probs',
#  'save_crop',
#  'save_txt',
#  'speed',
#  'to',
#  'tojson',
#  'update',
#  'verbose']

# %%
results[0].boxes.data
# Out:
# tensor([[2.6275e+02, 1.1186e+02, 5.8670e+02, 5.3501e+02, 9.3537e-01, 0.0000e+00],
#         [5.8927e+02, 2.1384e+02, 7.3402e+02, 3.3946e+02, 8.3311e-01, 6.2000e+01],
#         [7.0990e+02, 1.5469e+02, 9.5974e+02, 5.3555e+02, 8.3197e-01, 0.0000e+00],
#         [4.6800e+02, 1.3103e+02, 5.6035e+02, 2.2839e+02, 8.0842e-01, 0.0000e+00],
#         [2.7132e-01, 2.1302e+02, 2.3334e+02, 4.2156e+02, 7.7533e-01, 6.2000e+01],
#         [2.0416e-02, 1.2749e+02, 5.0704e+01, 1.8734e+02, 7.2222e-01, 0.0000e+00],
#         [2.7584e+01, 1.3385e+02, 1.7546e+02, 2.2529e+02, 6.3817e-01, 0.0000e+00],
#         [9.3054e+01, 2.2467e+00, 1.7194e+02, 1.4004e+02, 5.8320e-01, 5.8000e+01],
#         [5.5373e+02, 3.4986e+02, 7.2332e+02, 5.3556e+02, 5.8189e-01, 5.6000e+01],
#         [1.5059e+02, 4.5594e+02, 2.8415e+02, 5.2028e+02, 5.3192e-01, 6.6000e+01],
#         [2.1075e+02, 1.5867e+02, 2.9659e+02, 3.8016e+02, 5.2530e-01, 0.0000e+00],
#         [4.6619e+02, 2.1580e+02, 5.7386e+02, 3.3528e+02, 4.9620e-01, 6.2000e+01],
#         [2.3186e+02, 1.3152e+02, 2.7979e+02, 1.6918e+02, 4.3891e-01, 0.0000e+00],
#         [5.5464e+02, 3.4938e+02, 8.2317e+02, 5.3489e+02, 4.2851e-01, 5.6000e+01],
#         [4.6664e+02, 2.1619e+02, 5.7294e+02, 3.3491e+02, 4.1604e-01, 6.3000e+01],
#         [0.0000e+00, 1.8635e+02, 4.8672e+01, 2.2716e+02, 3.8262e-01, 6.3000e+01],
#         [2.0915e+02, 1.6112e+02, 3.4053e+02, 3.9696e+02, 3.3405e-01, 0.0000e+00],
#         [2.3191e+02, 1.3191e+02, 2.8471e+02, 1.9934e+02, 3.0896e-01, 0.0000e+00]])

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image

# %%
a = plt.imshow(Image.open('test.jpg'))

for x,y,w,h in results[0].boxes.xywh:
    plt.gca().add_patch(Rectangle((x,y), 10,10,
                    edgecolor='red',
                    facecolor='none',
                    lw=1))

# %%
a.get_size()
# Out:
# (246, 723)
